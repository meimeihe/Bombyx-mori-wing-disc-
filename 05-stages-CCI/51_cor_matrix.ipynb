# %%
library(ggplot2)
library(Seurat)
library(corrplot)
library(pheatmap)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.3.3”
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
# corrplot 0.92 loaded

# %%
load("./cor_all.Rdata")

# %%
pmt <- p_table.species1
ssmt <- pmt< 0.01
pmt[ssmt] <-'**'
smt <- pmt >0.01& pmt <0.05
pmt[smt] <- '*'
pmt[!ssmt&!smt]<- ''

# %%
p1<-pheatmap(comp_table.species1,
             show_colnames = T,show_rownames = T,fontsize = 14,
             cluster_rows = F,cluster_cols = F,border_color = "NA",
             # color = colorRampPalette(c("darkblue", "white","darkred"))(256),
             color = colorRampPalette(c("#1f77b4", "white","#ff9896"))(256),
             display_numbers = pmt,legend_breaks=seq(0,1,0.2),
             fontsize_number = 12, number_color = "black")
pdf("cor_all_genes_cluster.pdf",width = 8,height = 8)
print(p1)
dev.off()
# Out:
# png
#   2
# plot without title
