# %%
# coding: utf-8
# spateo_1.0.2 envs
import os
import sys
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import skimage
import sklearn
import pandas as pd
import anndata 
import spateo as st
import dynamo as dyn
import cv2


from scipy import stats
import pickle

import cdlib 
import matplotlib as mpl
from matplotlib import rcParams
mpl.rcParams['pdf.fonttype'] = 42
import scanpy as sc
# Out:
# 2025-02-28 10:23:18.740697: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-28 10:23:19.369340: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-28 10:23:21.079136: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-28 10:23:29.782116: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
plt.style.use('default')
plt.rcParams['image.interpolation'] = 'none'


np.random.seed(0)

# %%
adata=anndata.read("/hsfscqjf1/ST_CQ/P24Z32300N0020/hemingmin/bom/10.sn_merged2/results/6_hdWGCNA/hdwgcna.h5ad")

# %%
sc.pp.scale(adata)

# %%
features=['all_degs-M1','all_degs-M2']

# %%
ax=sc.pl.dotplot(adata, features, 'timepoint', 
                figsize=[3.5,3],
                 vmin=-1,vmax=1,
                 dot_max=0.7,
                 dot_min=0,
                 cmap='bwr',var_group_rotation=0,
                save='markers1_timepoint.pdf')
# Out:
# WARNING: saving figure to file figures/dotplot_markers1_timepoint.pdf

# %%
ax=sc.pl.dotplot(adata, features, 'celltype', 
                figsize=[3.5,3],
                 vmin=-1,vmax=1,
                 dot_max=0.7,
                 dot_min=0,
                 cmap='bwr',var_group_rotation=0,
                save='markers1_celltype.pdf')
# Out:
# WARNING: saving figure to file figures/dotplot_markers1_celltype.pdf
